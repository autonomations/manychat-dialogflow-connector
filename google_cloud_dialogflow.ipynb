# %%
from google.cloud import dialogflow_v2 as df

# %%
df.Intent??
# Out:
# Init signature: df.Intent(mapping=None, *, ignore_unknown_fields=False, **kwargs)
# Source:
# class Intent(proto.Message):
#     r"""An intent categorizes an end-user's intention for one conversation
#     turn. For each agent, you define many intents, where your combined
#     intents can handle a complete conversation. When an end-user writes
#     or says something, referred to as an end-user expression or end-user
#     input, Dialogflow matches the end-user input to the best intent in
#     your agent. Matching an intent is also known as intent
#     classification.
#
#     For more information, see the `intent
#     guide <https://cloud.google.com/dialogflow/docs/intents-overview>`__.
#
#     Attributes:
#         name (str):
#             Optional. The unique identifier of this intent. Required for
#             [Intents.UpdateIntent][google.cloud.dialogflow.v2.Intents.UpdateIntent]
#             and
# ...

# %%
from google.cloud import dialogflow_v2beta1 as dialogflow_v2

def sample_list_intents():
    client = dialogflow_v2.IntentsClient()

    request = dialogflow_v2.ListIntentsRequest(
        parent="parent_value",
    )

    page_result = client.list_intents(request=request)
    
    for response in page_result:
        print(response)

# %%
dialogflow_v2.Intent??
# Out:
# Init signature:
# dialogflow_v2.Intent(
#     mapping=None,
#     *,
#     ignore_unknown_fields=False,
#     **kwargs,
# )
# Source:
# class Intent(proto.Message):
#     r"""An intent categorizes an end-user's intention for one conversation
#     turn. For each agent, you define many intents, where your combined
#     intents can handle a complete conversation. When an end-user writes
#     or says something, referred to as an end-user expression or end-user
#     input, Dialogflow matches the end-user input to the best intent in
#     your agent. Matching an intent is also known as intent
#     classification.
#
#     For more information, see the `intent
#     guide <https://cloud.google.com/dialogflow/docs/intents-overview>`__.
#
#     Attributes:
#         name (str):
#             Optional. The unique identifier of this intent. Required for
#             [Intents.UpdateIntent][google.cloud.dialogflow.v2beta1.Intents.UpdateIntent]
#             and
# ...

# %%
sample_list_intents()
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# /var/folders/w0/z07p93y54bz2zqjzp7v4v4nm0000gn/T/ipykernel_25753/4232607801.py in <module>
# ----> 1 sample_list_intents()
#
# /var/folders/w0/z07p93y54bz2zqjzp7v4v4nm0000gn/T/ipykernel_25753/4070943452.py in sample_list_intents()
#       3 def sample_list_intents():
#       4     # Create a client
# ----> 5     client = dialogflow_v2.IntentsClient()
#       6
#       7     # Initialize request argument(s)
#
# ~/miniconda3/envs/py37/lib/python3.8/site-packages/google/cloud/dialogflow_v2beta1/services/intents/client.py in __init__(self, credentials, transport, client_options, client_info)
#     440
#     441             Transport = type(self).get_transport_class(transport)
# --> 442             self._transport = Transport(
#     443                 credentials=credentials,
# ...
